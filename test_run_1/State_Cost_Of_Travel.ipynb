# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
acc = pd.read_csv('accommodations.csv')

# %%
acc.head()
# Out:
#   merch_state  month_date  accommodation_cost  transaction_count  \
# 0          FL  2025-06-01          214.320007            2940781
# 1          CA  2025-06-01          225.399994            2723295
# 2          TX  2025-06-01          200.330002            2711451
# 3          NV  2025-06-01          192.130005            1968224
# 4          TN  2025-06-01          207.639999            1428481
#
#    unique_visitors   min_cost     max_cost         q25         q75  \
# 0            12806  56.270000  2850.500000  117.589996  458.290009
# 1            13628  60.009998  2055.679932  118.089996  426.779999
# 2            12908  57.630001  1433.630005  123.070000  378.690002
# 3             8067  60.380001  1359.060059  109.169998  349.179993
# 4             6557  56.810001  1692.209961  123.040001  392.399994
#
#   data_quality_flag period_start  period_end           calculation_timestamp
# 0      SINGLE_MONTH   2025-06-01  2025-08-31  2025-11-17 19:45:31.936689 UTC
# ...

# %%
acc.month_date.unique()
# Out:
# array(['2025-06-01', '2025-07-01', '2025-08-01'], dtype=object)

# %%
acc.sort_values(by='unique_visitors', ascending=True)[:10]
# Out:
#    merch_state  month_date  accommodation_cost  transaction_count  \
# 51          XX  2025-06-01         1107.770020                  6
# 49          VT  2025-06-01          292.200012             117460
# 50          RI  2025-06-01          323.049988              95194
# 47          DE  2025-06-01          225.350006             220856
# 46          NH  2025-06-01          252.160004             235179
# 48          ME  2025-06-01          300.579987             217060
# 43          DC  2025-06-01          337.320007             594681
# 44          ND  2025-06-01          194.669998             564400
# 41          ID  2025-06-01          220.320007             949414
# 45          CT  2025-06-01          209.720001             438712
#
#     unique_visitors    min_cost     max_cost         q25          q75  \
# 51                1  201.699997  1145.930054  201.699997  1145.930054
# 49              681   74.080002  1892.949951  183.029999   573.869995
# ...

# %%
att = pd.read_csv('attractions.csv')

# %%
att.head()
# Out:
#   merch_state  month_date  attraction_cost  transaction_count  \
# 0          NH  2025-06-01         8.290000            3824413
# 1          XX  2025-06-01        16.129999               4197
# 2          TX  2025-06-01        18.780001           19098336
# 3          GA  2025-06-01        19.840000           12437625
# 4          NY  2025-06-01        20.250000           21169288
#
#    unique_visitors data_quality_flag period_start  period_end  \
# 0            18239      SINGLE_MONTH   2025-06-01  2025-08-31
# 1               81      SINGLE_MONTH   2025-06-01  2025-08-31
# 2            75407      SINGLE_MONTH   2025-06-01  2025-08-31
# 3            27959      SINGLE_MONTH   2025-06-01  2025-08-31
# 4            58295      SINGLE_MONTH   2025-06-01  2025-08-31
#
#             calculation_timestamp
# 0  2025-11-17 19:27:20.203618 UTC
# 1  2025-11-17 19:27:20.203618 UTC
# 2  2025-11-17 19:27:20.203618 UTC
# 3  2025-11-17 19:27:20.203618 UTC
# 4  2025-11-17 19:27:20.203618 UTC

# %%
att.sort_values(by='unique_visitors', ascending=True)[:10]
# Out:
#    merch_state  month_date  attraction_cost  transaction_count  \
# 1           XX  2025-06-01        16.129999               4197
# 40          RI  2025-06-01        32.200001             103091
# 6           VT  2025-06-01        20.950001             140574
# 15          ND  2025-06-01        23.090000             261188
# 41          MT  2025-06-01        32.439999             326240
# 44          CT  2025-06-01        34.959999             523650
# 47          ME  2025-06-01        35.770000             270048
# 9           WY  2025-06-01        22.030001             892138
# 20          DC  2025-06-01        25.190001             269187
# 36          HI  2025-06-01        30.660000            1319120
#
#     unique_visitors data_quality_flag period_start  period_end  \
# 1                81      SINGLE_MONTH   2025-06-01  2025-08-31
# 40              749      SINGLE_MONTH   2025-06-01  2025-08-31
# 6              1218      SINGLE_MONTH   2025-06-01  2025-08-31
# ...

# %%
att.head()
# Out:
#   merch_state  month_date  attraction_cost  transaction_count  \
# 0          NH  2025-06-01         8.290000            3824413
# 1          XX  2025-06-01        16.129999               4197
# 2          TX  2025-06-01        18.780001           19098336
# 3          GA  2025-06-01        19.840000           12437625
# 4          NY  2025-06-01        20.250000           21169288
#
#    unique_visitors data_quality_flag period_start  period_end  \
# 0            18239      SINGLE_MONTH   2025-06-01  2025-08-31
# 1               81      SINGLE_MONTH   2025-06-01  2025-08-31
# 2            75407      SINGLE_MONTH   2025-06-01  2025-08-31
# 3            27959      SINGLE_MONTH   2025-06-01  2025-08-31
# 4            58295      SINGLE_MONTH   2025-06-01  2025-08-31
#
#             calculation_timestamp
# 0  2025-11-17 19:27:20.203618 UTC
# 1  2025-11-17 19:27:20.203618 UTC
# 2  2025-11-17 19:27:20.203618 UTC
# 3  2025-11-17 19:27:20.203618 UTC
# 4  2025-11-17 19:27:20.203618 UTC

# %%
att.sort_values(by='unique_visitors', ascending=True)[:10]
# Out:
#    merch_state  month_date  attraction_cost  transaction_count  \
# 1           XX  2025-06-01        16.129999               4197
# 40          RI  2025-06-01        32.200001             103091
# 6           VT  2025-06-01        20.950001             140574
# 15          ND  2025-06-01        23.090000             261188
# 41          MT  2025-06-01        32.439999             326240
# 44          CT  2025-06-01        34.959999             523650
# 47          ME  2025-06-01        35.770000             270048
# 9           WY  2025-06-01        22.030001             892138
# 20          DC  2025-06-01        25.190001             269187
# 36          HI  2025-06-01        30.660000            1319120
#
#     unique_visitors data_quality_flag period_start  period_end  \
# 1                81      SINGLE_MONTH   2025-06-01  2025-08-31
# 40              749      SINGLE_MONTH   2025-06-01  2025-08-31
# 6              1218      SINGLE_MONTH   2025-06-01  2025-08-31
# ...

# %%
rest = pd.read_csv('restaurants.csv')

# %%
rest.head()
# Out:
#   merch_state  month_date  breakfast_lunch_cost  dinner_cost  \
# 0          XX  2025-06-01              9.310000    15.180000
# 1          DE  2025-06-01              7.500000    21.709999
# 2          OK  2025-06-01             15.090000    30.990000
# 3          DC  2025-06-01             16.139999    32.740002
# 4          UT  2025-06-01             17.120001    33.939999
#
#    median_meal_cost  transaction_count  unique_visitors data_quality_flag  \
# 0         11.820000              13160               68      SINGLE_MONTH
# 1         11.300000            6540403            21514      SINGLE_MONTH
# 2         21.260000           26816366            59090      SINGLE_MONTH
# 3         22.160000            3482299            13563      SINGLE_MONTH
# 4         24.139999            9232578            33510      SINGLE_MONTH
#
#   period_start  period_end           calculation_timestamp
# 0   2025-06-01  2025-08-31  2025-11-17 19:28:41.001477 UTC
# ...

# %%
rest.sort_values(by='unique_visitors', ascending=True)[:10]
# Out:
#    merch_state  month_date  breakfast_lunch_cost  dinner_cost  \
# 0           XX  2025-06-01              9.310000    15.180000
# 10          VT  2025-06-01             18.340000    38.480000
# 42          RI  2025-06-01             21.920000    46.650002
# 13          ND  2025-06-01             20.180000    39.040001
# 22          CT  2025-06-01             20.379999    40.840000
# 51          NH  2025-06-01             29.360001    56.820000
# 3           DC  2025-06-01             16.139999    32.740002
# 50          ME  2025-06-01             26.760000    56.310001
# 27          WY  2025-06-01             22.340000    42.209999
# 38          MT  2025-06-01             22.950001    44.400002
#
#     median_meal_cost  transaction_count  unique_visitors data_quality_flag  \
# 0          11.820000              13160               68      SINGLE_MONTH
# 10         25.969999            1104548             5209      SINGLE_MONTH
# ...

# %%
ret = pd.read_csv('retail.csv')

# %%
ret.head()
# Out:
#   merch_state  month_date  retail_cost  transaction_count  unique_visitors  \
# 0          CA  2025-06-01    29.750000          333567194           544979
# 1          NY  2025-06-01    43.070000           57980492           244715
# 2          FL  2025-06-01    39.500000           57816634           207822
# 3          TX  2025-06-01    42.549999           47081150           175356
# 4          OH  2025-06-01    54.419998           37032453           124611
#
#   data_quality_flag period_start  period_end           calculation_timestamp
# 0      SINGLE_MONTH   2025-06-01  2025-08-31  2025-11-17 19:31:47.658768 UTC
# 1      SINGLE_MONTH   2025-06-01  2025-08-31  2025-11-17 19:31:47.658768 UTC
# 2      SINGLE_MONTH   2025-06-01  2025-08-31  2025-11-17 19:31:47.658768 UTC
# 3      SINGLE_MONTH   2025-06-01  2025-08-31  2025-11-17 19:31:47.658768 UTC
# 4      SINGLE_MONTH   2025-06-01  2025-08-31  2025-11-17 19:31:47.658768 UTC

# %%
ret.sort_values(by='unique_visitors', ascending=True)[:10]
# Out:
#    merch_state  month_date  retail_cost  transaction_count  unique_visitors  \
# 51          XX  2025-06-01   154.229996                 74                6
# 49          DC  2025-06-01    25.639999            1067959             5073
# 50          RI  2025-06-01    37.009998            1034470             5951
# 48          VT  2025-06-01    51.799999            2923568             7657
# 42          WV  2025-06-01    37.279999            3975488            13248
# 45          NE  2025-06-01    42.430000            3276481            13553
# 47          ME  2025-06-01    35.470001            3078248            13767
# 46          NH  2025-06-01    39.119999            3160845            16409
# 44          ND  2025-06-01    54.840000            3518078            16487
# 41          MT  2025-06-01    38.020000            4184011            17055
#
#    data_quality_flag period_start  period_end           calculation_timestamp
# ...

# %%
merge_1 = pd.merge(acc, att, how='left', on=['merch_state', 'month_date'], suffixes=("_acc", "_att"))

# %%
merge_2 = pd.merge(rest, ret, how='left', on=['merch_state', 'month_date'], suffixes=("_rest", "_ret"))

# %%
final = pd.merge(merge_1, merge_2, how='left', on=['merch_state', 'month_date'])

# %%
final.month_date.unique()
# Out:
# array(['2025-06-01'], dtype=object)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   merch_state                 52 non-null     object
#  1   month_date                  52 non-null     object
#  2   accommodation_cost          52 non-null     float64
#  3   transaction_count_acc       52 non-null     int64
#  4   unique_visitors_acc         52 non-null     int64
#  5   min_cost                    52 non-null     float64
#  6   max_cost                    52 non-null     float64
#  7   q25                         52 non-null     float64
#  8   q75                         52 non-null     float64
#  9   data_quality_flag_acc       52 non-null     object
#  10  period_start_acc            52 non-null     object
#  11  period_end_acc              52 non-null     object
#  12  calculation_timestamp_acc   52 non-null     object
# ...

# %%
trim = final[['merch_state', 'accommodation_cost', 'attraction_cost', 'breakfast_lunch_cost', 'dinner_cost', 'median_meal_cost', 
              'retail_cost']]

# %%
trim.head()
# Out:
#   merch_state  accommodation_cost  attraction_cost  breakfast_lunch_cost  \
# 0          CA          226.210007        21.980000             20.889999
# 1          FL          204.929993        45.349998             27.030001
# 2          TX          191.289993        18.900000             21.360001
# 3          NV          200.199997        28.559999             24.590000
# 4          TN          201.539993        31.639999             25.309999
#
#    dinner_cost  median_meal_cost  retail_cost
# 0    43.700001         30.049999    29.719999
# 1    57.279999         39.570000    40.610001
# 2    41.990002         29.950001    42.189999
# 3    48.939999         34.340000    26.410000
# 4    46.509998         35.509998    40.919998

# %%
trim['cost_per_trip'] = (trim['accommodation_cost']*2)+ (trim['attraction_cost']*2)+ (trim['breakfast_lunch_cost']*4)+ (trim['dinner_cost']*2)+ (trim['retail_cost']*2)
# Out:
# /var/folders/tt/3g3mlsjs2ns5s373578hytch0000gp/T/ipykernel_31435/4074024167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trim['cost_per_trip'] = (trim['accommodation_cost']*2)+ (trim['attraction_cost']*2)+ (trim['breakfast_lunch_cost']*4)+ (trim['dinner_cost']*2)+ (trim['retail_cost']*2)

# %%
trim.head()
# Out:
#   merch_state  accommodation_cost  attraction_cost  breakfast_lunch_cost  \
# 0          FL          205.309998        44.990002             27.040001
# 1          CA          221.559998        20.930000             20.900000
# 2          TX          190.220001        18.879999             21.650000
# 3          NV          193.809998        30.610001             24.570000
# 4          TN          199.919998        32.849998             26.000000
#
#    dinner_cost  median_meal_cost  retail_cost  cost_per_trip
# 0    57.669998         39.830002    40.029999     804.159996
# 1    43.590000         30.090000    29.700001     715.159996
# 2    42.730000         30.510000    40.790001     671.840000
# 3    48.680000         34.240002    25.430000     695.339996
# 4    46.869999         36.139999    39.919998     743.119987

# %%
trim = trim.loc[trim['merch_state'] !='XX']

# %%
trim.to_csv('July_month_test.csv', index=False)
